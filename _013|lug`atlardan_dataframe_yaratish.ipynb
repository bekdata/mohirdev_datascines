# %% [markdown]
# <a href="https://colab.research.google.com/github/bekdata/mohirdev_datascines/blob/main/_013%7Clug%60atlardan_dataframe_yaratish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
#  data malumot yaratish
data = {
    't_yil' :[ ]
}
# Out:
# {'t_til': ['2000', '2001', '2002', '2003', '2004'],
#  'names': ['Jek', 'Ali', 'Vali', 'Hasan', 'Husan'],
#  'age': [10, 20, 30, 40, 50]}

# %%
# shu malumotlarni dataframe ko`rinishiga o`tkazish
df = DataFrame(data, columns=['t_yil', 'names', 'age'])
df
# Out:
#   t_yil  names  age
# 0   NaN    Jek   10
# 1   NaN    Ali   20
# 2   NaN   Vali   30
# 3   NaN  Hasan   40
# 4   NaN  Husan   50

# %%
df.head(3)   # dataning birinchi 3 ta qatorini chiqarish
# Out:
#   t_yil  names  age
# 0   NaN    Jek   10
# 1   NaN    Ali   20
# 2   NaN   Vali   30
# 3   NaN  Hasan   40
# 4   NaN  Husan   50

# %%
# alohida bitta ustunni ajratish
df.t_yil
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: t_yil, dtype: object

# %%
df.age   # age ustunini ajratib olish
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: age, dtype: int64

# %%
df['manzil'] = 'Jarqorgon'  # manzil ustunini qo`shishi va unga qiymat berish

# %%
del df["t_yil"]   # kerak bo`lmagan ustunni o`chirish
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 't_yil'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-0ec5d15f4d07> in <cell line: 0>()
# ----> 1 del df["t_yil"]
#
# ...

# %%
df
# Out:
#    names  age     manzil
# 0    Jek   10  Jarqorgon
# 1    Ali   20  Jarqorgon
# 2   Vali   30  Jarqorgon
# 3  Hasan   40  Jarqorgon
# 4  Husan   50  Jarqorgon

# %%
data1 = {
    'uzbekistan' : {2021:10,2020:9.9,2019:9.5,2018:9.0},
    'kazakstan' : {2021:8.9,2020:8.1,2019:7.9,2018:7.5}
}
data1
# Out:
# {'uzbekistan': {2021: 10, 2020: 9.9, 2019: 9.5, 2018: 9.0},
#  'kazakstan': {2021: 8.9, 2020: 8.1, 2019: 7.9, 2018: 7.5}}

# %%
df = DataFrame(data)
df
# Out:
#       uzbekistan  kazakstan
# 2021        10.0        8.9
# 2020         9.9        8.1
# 2019         9.5        7.9
# 2018         9.0        7.5

# %%
df.index.name = "yil"   # ustunlarga nom qo`yish
df
# Out:
#       uzbekistan  kazakstan
# yil
# 2021        10.0        8.9
# 2020         9.9        8.1
# 2019         9.5        7.9
# 2018         9.0        7.5

# %%
df = DataFrame(data, index=[2021,2020, 2019,2018])     # alohida qatorlarni chiqarib olish
df
# Out:
#       uzbekistan  kazakstan
# 2021        10.0        8.9
# 2020         9.9        8.1
# 2019         9.5        7.9
# 2018         9.0        7.5

# %%
df.index      # dataframe dagi index qiymatlarni chiqarish
# Out:
# Index([2021, 2020, 2019, 2018], dtype='int64')

# %%
df.values     # malumot qatorlarini chiqarish
# Out:
# array([[10. ,  8.9],
#        [ 9.9,  8.1],
#        [ 9.5,  7.9],
#        [ 9. ,  7.5]])

# %%
"Tadjikistan" in df.columns    # qiymatni ustun nomlaridan tekshirish
# Out:
# False

# %%
2020 in df.index      # qator malumotlarini tekshirish
# Out:
# True

# %%
df.index.drop(2020)    # 2020 index qiymatini olib tashlash
# Out:
# Index([2021, 2019, 2018], dtype='int64')

# %%
df.index.delete(0)    # birinchi index dagi qiymatni o`chirib tashlash
# Out:
# Index([2020, 2019, 2018], dtype='int64')
