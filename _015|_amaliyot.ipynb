# %% [markdown]
# <a href="https://colab.research.google.com/github/bekdata/mohirdev_datascines/blob/main/_015%7C_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.Series(["Toshkent","Samarqand", "Buxoro", "Qarshi", "Surxondaryo"])
print(data)
# Out:
# 0       Toshkent
# 1      Samarqand
# 2         Buxoro
# 3         Qarshi
# 4    Surxondaryo
# dtype: object

# %%
print(type(data))   # yarailgan series elementi
# Out:
# <class 'pandas.core.series.Series'>

# %%
data[0]    # seriesning birirnchi qiymatini chiqarish
# Out:
# 'Toshkent'

# %%
data[4]     # oxirgi elementini chiqarish
# Out:
# 'Surxondaryo'

# %%
data.size   # series elementlari sonini chiqaring
# Out:
# 5

# %%
data[:3]   # elementning birinchi 3 ta qiymatini chiqarish
# Out:
# 0     Toshkent
# 1    Samarqand
# 2       Buxoro
# dtype: object

# %%
df = pd.DataFrame(data)
df   # series elemntini dataframe ko`rinishiga o`tkazish
# Out:
#              0
# 0     Toshkent
# 1    Samarqand
# 2       Buxoro
# 3       Qarshi
# 4  Surxondaryo

# %%
df['axoli'] = [23,20,19,15,19]
df
# Out:
#              0  axoli
# 0     Toshkent     23
# 1    Samarqand     20
# 2       Buxoro     19
# 3       Qarshi     15
# 4  Surxondaryo     19

# %%
df.index.name = 'index'
df
# Out:
#                  0  axoli
# index
# 0         Toshkent     23
# 1        Samarqand     20
# 2           Buxoro     19
# 3           Qarshi     15
# 4      Surxondaryo     19

# %%
df_sort = df.sort_values('axoli')     # dataframe ning axoli ustunu bo`yicha sort qilish
df_sort
# Out:
#                  0  axoli
# index
# 3           Qarshi     15
# 2           Buxoro     19
# 4      Surxondaryo     19
# 1        Samarqand     20
# 0         Toshkent     23
