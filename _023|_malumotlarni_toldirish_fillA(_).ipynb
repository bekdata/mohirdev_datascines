# %% [markdown]
# <a href="https://colab.research.google.com/github/bekdata/mohirdev_datascines/blob/main/_023%7C_malumotlarni_toldirish_fillA(_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/automobile_data_nan.csv')
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
# hamma NaN qiymatlarini 0 bilan almashtirish
df.fillna(0)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         0.0   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         0.0   171.7           0
# 58     86   volkswagen        sedan        97.3     0.0         ohc
# 59     87        volvo        sedan       104.3   188.8           0
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         0.0             21.0  13495.0
# ...

# %%
# malumot mavjud
df.fillna({'horsepower':100})
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four       100.0             21.0  13495.0
# ...

# %%
# bir xil malumotga ega bolgan aatorlarni ajratish
df[df.company=='audi']
# Out:
#    index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3      3    audi      sedan        99.8   176.6         ohc             four
# 4      4    audi      sedan        99.4   176.6         ohc             five
# 5      5    audi      sedan        99.8   177.3         ohc             five
# 6      6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3       102.0             24.0  13950.0
# 4         NaN              NaN  17450.0
# 5       110.0             19.0  15250.0
# 6       110.0             19.0  18920.0

# %%
# o`zidan oldingi malumotga qarab to`ldirish
df[df.company=='audi'].fillna(method='ffill')
# Out:
# <ipython-input-14-69bb620c3c9f>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[df.company=='audi'].fillna(method='ffill')
#    index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3      3    audi      sedan        99.8   176.6         ohc             four
# 4      4    audi      sedan        99.4   176.6         ohc             five
# 5      5    audi      sedan        99.8   177.3         ohc             five
# 6      6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3       102.0             24.0  13950.0
# 4       102.0             24.0  17450.0
# 5       110.0             19.0  15250.0
# 6       110.0             19.0  18920.0

# %%
# ma`lumot yoq qatorni o`zidan keyingi qator malumotlari bilan to`ldirish
df.fillna(method='bfill')
# Out:
# <ipython-input-20-aa809c387376>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        94.5   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   188.8         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# ...

# %%
df.fillna(method=)
