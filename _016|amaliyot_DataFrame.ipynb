# %% [markdown]
# <a href="https://colab.research.google.com/github/bekdata/mohirdev_datascines/blob/main/_016%7Camaliyot_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
viloyatlar = [
    "Andijon viloyati",
    "Buxoro viloyati",
    "Fargona viloyati",
    "Jizzax viloyati",
    "Xorazm viloyati",
    "Namangan viloyati",
    "Navoiy viloyati",
    "Qashqadaryo viloyati",
    "Qoraqalpogʻiston Respublikasi",
    "Samarqand viloyati",
    "Sirdaryo viloyati",
    "Surxondaryo viloyati",
    "Toshkent viloyati",
]

markazlar = [
    "Andijon shahri",
    "Buxoro shahri",
    "Fargona shahri",
    "Jizzax shahri",
    "Urganch shahri",
    "Namangan shahri",
    "Navoiy shahri",
    "Qarshi shahri",
    "Nukus shahri",
    "Samarqand shahri",
    "Guliston shahri",
    "Termiz shahri",
    "Nurafshon shahri",
]

maydonlar = [
    4200,
    39400,
    6800,
    20500,
    6300,
    7900,
    110800,
    28400,
    160000,
    16400,
    5100,
    20800,
    15300,
]

aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
data = {
    "Hudud": viloyatlar,
    'Markaz': markazlar,
    "Maydon": maydonlar,
    "Axoli": aholi
}

df = pd.DataFrame(data)
df
# Out:
#                             Hudud            Markaz  Maydon    Axoli
# 0                Andijon viloyati    Andijon shahri    4200  1899000
# 1                 Buxoro viloyati     Buxoro shahri   39400  1384700
# 2                Fargona viloyati    Fargona shahri    6800  2597000
# 3                 Jizzax viloyati     Jizzax shahri   20500   910500
# 4                 Xorazm viloyati    Urganch shahri    6300  1200000
# 5               Namangan viloyati   Namangan shahri    7900  1862000
# 6                 Navoiy viloyati     Navoiy shahri  110800   767500
# 7            Qashqadaryo viloyati     Qarshi shahri   28400  2029000
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri  160000  1200000
# 9              Samarqand viloyati  Samarqand shahri   16400  2322000
# 10              Sirdaryo viloyati   Guliston shahri    5100   648100
# 11           Surxondaryo viloyati     Termiz shahri   20800  1676000
# 12              Toshkent viloyati  Nurafshon shahri   15300  4450000

# %%
df.head()   # 5 ta qatorni chiqarish
# Out:
#               Hudud          Markaz  Maydon    Axoli
# 0  Andijon viloyati  Andijon shahri    4200  1899000
# 1   Buxoro viloyati   Buxoro shahri   39400  1384700
# 2  Fargona viloyati  Fargona shahri    6800  2597000
# 3   Jizzax viloyati   Jizzax shahri   20500   910500
# 4   Xorazm viloyati  Urganch shahri    6300  1200000

# %%
df.tail()      # oxirgi 5 ta qatorni cjiqarish uchun
# Out:
#                             Hudud            Markaz  Maydon    Axoli
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri  160000  1200000
# 9              Samarqand viloyati  Samarqand shahri   16400  2322000
# 10              Sirdaryo viloyati   Guliston shahri    5100   648100
# 11           Surxondaryo viloyati     Termiz shahri   20800  1676000
# 12              Toshkent viloyati  Nurafshon shahri   15300  4450000

# %%
df.sample(3)    # ixtiyoriy n ta qatorni chiqarish
# Out:
#               Hudud          Markaz  Maydon    Axoli
# 3   Jizzax viloyati   Jizzax shahri   20500   910500
# 0  Andijon viloyati  Andijon shahri    4200  1899000
# 2  Fargona viloyati  Fargona shahri    6800  2597000

# %%
df[['Hudud', 'Axoli']]    # berilgan iki ustun malumotlarini chiqarish
# Out:
#                             Hudud    Axoli
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2                Fargona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %%
df['Markaz']   # ushbu ustunni Series ko`rinishida chiqarish uchun
# Out:
# 0       Andijon shahri
# 1        Buxoro shahri
# 2       Fargona shahri
# 3        Jizzax shahri
# 4       Urganch shahri
# 5      Namangan shahri
# 6        Navoiy shahri
# 7        Qarshi shahri
# 8         Nukus shahri
# 9     Samarqand shahri
# 10     Guliston shahri
# 11       Termiz shahri
# 12    Nurafshon shahri
# Name: Markaz, dtype: object

# %%
df[df['Axoli'] > 2000000]   # axoli qiymati bo`yicha ajratish
# Out:
#                    Hudud            Markaz  Maydon    Axoli
# 2       Fargona viloyati    Fargona shahri    6800  2597000
# 7   Qashqadaryo viloyati     Qarshi shahri   28400  2029000
# 9     Samarqand viloyati  Samarqand shahri   16400  2322000
# 12     Toshkent viloyati  Nurafshon shahri   15300  4450000

# %%
df[df.Maydon <10000]    # hudud ma`lumotlari bo`yicha saralash
# Out:
#                 Hudud           Markaz  Maydon    Axoli
# 0    Andijon viloyati   Andijon shahri    4200  1899000
# 2    Fargona viloyati   Fargona shahri    6800  2597000
# 4     Xorazm viloyati   Urganch shahri    6300  1200000
# 5   Namangan viloyati  Namangan shahri    7900  1862000
# 10  Sirdaryo viloyati  Guliston shahri    5100   648100

# %%
df_data = pd.DataFrame(data).set_index('Hudud')
df_data
# Out:
#                                          Markaz  Maydon    Axoli
# Hudud
# Andijon viloyati                 Andijon shahri    4200  1899000
# Buxoro viloyati                   Buxoro shahri   39400  1384700
# Fargona viloyati                 Fargona shahri    6800  2597000
# Jizzax viloyati                   Jizzax shahri   20500   910500
# Xorazm viloyati                  Urganch shahri    6300  1200000
# Namangan viloyati               Namangan shahri    7900  1862000
# Navoiy viloyati                   Navoiy shahri  110800   767500
# Qashqadaryo viloyati              Qarshi shahri   28400  2029000
# Qoraqalpogʻiston Respublikasi      Nukus shahri  160000  1200000
# Samarqand viloyati             Samarqand shahri   16400  2322000
# Sirdaryo viloyati               Guliston shahri    5100   648100
# Surxondaryo viloyati              Termiz shahri   20800  1676000
# Toshkent viloyati              Nurafshon shahri   15300  4450000

# %%
df[df.Axoli > 2000000]   # axoli soni bo`yicha saralash
# Out:
#                    Hudud            Markaz  Maydon    Axoli
# 2       Fargona viloyati    Fargona shahri    6800  2597000
# 7   Qashqadaryo viloyati     Qarshi shahri   28400  2029000
# 9     Samarqand viloyati  Samarqand shahri   16400  2322000
# 12     Toshkent viloyati  Nurafshon shahri   15300  4450000

# %%
"Samarqand viloyati" in df[df.Axoli > 2000000].index    # qiymat mavjut yoki mavjud emasligini tekshirish
# Out:
# False

# %%
df_data
# Out:
#                                          Markaz  Maydon    Axoli
# Hudud
# Andijon viloyati                 Andijon shahri    4200  1899000
# Buxoro viloyati                   Buxoro shahri   39400  1384700
# Fargona viloyati                 Fargona shahri    6800  2597000
# Jizzax viloyati                   Jizzax shahri   20500   910500
# Xorazm viloyati                  Urganch shahri    6300  1200000
# Namangan viloyati               Namangan shahri    7900  1862000
# Navoiy viloyati                   Navoiy shahri  110800   767500
# Qashqadaryo viloyati              Qarshi shahri   28400  2029000
# Qoraqalpogʻiston Respublikasi      Nukus shahri  160000  1200000
# Samarqand viloyati             Samarqand shahri   16400  2322000
# Sirdaryo viloyati               Guliston shahri    5100   648100
# Surxondaryo viloyati              Termiz shahri   20800  1676000
# Toshkent viloyati              Nurafshon shahri   15300  4450000

# %%
df_data.loc[["Surxondaryo viloyati"]]     # ma`lumot ichidan faqat biita qator malumotlarini ajratib olish
# Out:
#                              Markaz  Maydon    Axoli
# Hudud
# Surxondaryo viloyati  Termiz shahri   20800  1676000

# %%
# axolisi kam hududlarni aniqlash
df_new = df.Axoli < 1500000
df_new
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# Name: Axoli, dtype: bool
