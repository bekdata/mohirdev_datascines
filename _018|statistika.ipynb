# %% [markdown]
# <a href="https://colab.research.google.com/github/bekdata/mohirdev_datascines/blob/main/_018%7Cstatistika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Keyingi mashqlar uchun ma'lumotlarni Githubdan yuklab olamiz
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni','aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum()   # data dagi ma`lumotlar yig`indisini hisoblash
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df.mean(axis=0)   # qator ma`lumotlari uchun o`rtacha qiymat
# Out:
# maydoni    3.399231e+04
# aholisi    1.765062e+06
# dtype: float64

# %%
df.idxmin()   # ustun turi bo`yicha eng kichik qiymatlarni qaytaradi
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: object

# %%
df.idxmax()     #ustun turlari bo`yicha eng katta qiymatlarni qaytaradi
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: object

# %%
print(df['aholisi'].idxmax(), 'axolisi eng kop') # bitta ustundan bitta eng katta va
print(df['maydoni'].idxmin(), 'hududi eng kichik')    #eng kichiq qiymatlarni qaytaris
# Out:
# Toshkent viloyati axolisi eng kop
# Andijon viloyati hududi eng kichik
